# %% [markdown]
# ## Housing Affordability in Austin, Texas
# Our analysis will go here

# %% [markdown]
# ## Data Import and Cleanup
# - Import dependencies
# - Load data into dataframes
# - Grab columns we want for analysis

# %%
# import data and dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# read in data into dataframes 
age_nativity = pd.read_csv("data/age_by_nativity.csv")
employment_by_industry = pd.read_csv("data/employment_by_industries.csv")
property_value = pd.read_csv("data/property_value.csv")
demographics = pd.read_csv("data/tdc_download_tool.csv")
wage_by_gender = pd.read_csv("data/wage_by_gender_in_common_jobs.csv")
wage_by_race = pd.read_csv("data/wage_by_race_and_ethnicity_in_common_jobs.csv")
wage_distribution = pd.read_csv("data/wage_distribution.csv")

employment_by_industry.head()
# Out:
#    ID Group                                              Group  ID Industry  \
# 0         9  Educational Services, & Health Care & Social A...           14
# 1        12                      Public Administration (Group)           19
# 2        11  Other Services, Except Public Administration (...           18
# 3         0  Agriculture, Forestry, Fishing & Hunting, & Mi...            1
# 4        10  Arts, Entertainment, & Recreation, & Accommoda...           17
#
#                                        Industry  ID Year  Year   ID State  \
# 0                          Educational Services     2017  2017  04000US48
# 1                         Public Administration     2017  2017  04000US48
# 2  Other Services, Except Public Administration     2017  2017  04000US48
# 3     Mining, Quarrying, & Oil & Gas Extraction     2017  2017  04000US48
# 4                 Accommodation & Food Services     2017  2017  04000US48
#
#    State  Workforce by Industry and Gender  \
# 0  Texas                             58591
# 1  Texas                             29054
# 2  Texas                             26993
# 3  Texas                              2802
# 4  Texas                             48958
#
#    Workforce by Industry and Gender Moe   Geography    ID Geography  \
# 0                           4083.898750  Austin, TX  16000US4805000
# 1                           2868.084378  Austin, TX  16000US4805000
# 2                           3119.346246  Austin, TX  16000US4805000
# 3                            875.727126  Austin, TX  16000US4805000
# 4                           3997.982741  Austin, TX  16000US4805000
#
#   Slug Geography
# 0      austin-tx
# 1      austin-tx
# 2      austin-tx
# 3      austin-tx
# 4      austin-tx

# %%
# grab columns we want about propery data 
property_value[['Value Bucket',
               'Year',
               'Property Value by Bucket',
               'Property Value by Bucket Moe',
               'Geography',
               'share']]
# Out:
#                  Value Bucket  Year  Property Value by Bucket  \
# 0           Less Than $10,000  2017                   1000376
# 1          $2,000,000 or More  2017                      2224
# 2          $15,000 to $19,999  2017                    484108
# 3          $20,000 to $24,999  2017                    537939
# 4          $25,000 to $29,999  2017                    495363
# 5          $30,000 to $34,999  2017                    596891
# 6          $35,000 to $39,999  2017                    447506
# 7          $40,000 to $49,999  2017                   1167440
# 8          $50,000 to $59,999  2017                   1398870
# 9          $60,000 to $69,999  2017                   1668358
# 10         $70,000 to $79,999  2017                   1920286
# 11         $80,000 to $89,999  2017                   2233308
# 12         $90,000 to $99,999  2017                   1944367
# 13       $100,000 to $124,999  2017                   5247464
# 14       $125,000 to $149,999  2017                   4961614
# 15       $150,000 to $174,999  2017                   6230138
# 16       $175,000 to $199,999  2017                   4565691
# 17       $200,000 to $249,999  2017                   8224555
# 18       $250,000 to $299,999  2017                   6839596
# 19       $300,000 to $399,999  2017                   9287497
# 20       $400,000 to $499,999  2017                   5516286
# 21       $500,000 to $749,999  2017                   6283285
# 22       $750,000 to $999,999  2017                   2488501
# 23   $1,000,000 to $1,499,999  2017                   1408667
# 24   $1,500,000 to $1,999,999  2017                    505125
# 25         $2,000,000 or More  2017                    680989
# 26         $10,000 to $14,999  2017                    549798
# 27          Less Than $10,000  2017                      1097
# 28         $10,000 to $14,999  2017                       447
# 29         $15,000 to $19,999  2017                       368
# ..                        ...   ...                       ...
# 126      $175,000 to $199,999  2015                     10798
# 127      $300,000 to $399,999  2015                   8274205
# 128        $15,000 to $19,999  2015                    500762
# 129      $200,000 to $249,999  2015                     24947
# 130        $20,000 to $24,999  2015                       535
# 131      $100,000 to $124,999  2015                   5842517
# 132      $250,000 to $299,999  2015                     19273
# 133      $400,000 to $499,999  2015                   4649695
# 134        $25,000 to $29,999  2015                       219
# 135      $300,000 to $399,999  2015                     25327
# 136         Less Than $10,000  2015                   1045716
# 137        $60,000 to $69,999  2015                   1874444
# 138      $400,000 to $499,999  2015                     17524
# 139        $30,000 to $34,999  2015                       364
# 140      $500,000 to $749,999  2015                   5243219
# 141      $500,000 to $749,999  2015                     20912
# 142      $125,000 to $149,999  2015                   5344324
# 143        $35,000 to $39,999  2015                       192
# 144      $750,000 to $999,999  2015                      5673
# 145        $35,000 to $39,999  2015                    485347
# 146      $750,000 to $999,999  2015                   2012603
# 147  $1,000,000 to $1,499,999  2015                      2496
# 148        $40,000 to $49,999  2015                       436
# 149        $25,000 to $29,999  2015                    523598
# 150  $1,500,000 to $1,999,999  2015                       819
# 151      $150,000 to $174,999  2015                   6487224
# 152        $50,000 to $59,999  2015                       716
# 153        $2,000,000 or More  2015                      1514
# 154  $1,000,000 to $1,499,999  2015                   1102169
# 155         Less Than $10,000  2015                      1377
#
#      Property Value by Bucket Moe      Geography     share
# 0                         16112.0  United States  0.013045
# 1                           832.0     Austin, TX  0.013137
# 2                         10315.0  United States  0.006313
# 3                          9802.0  United States  0.007015
# 4                         10768.0  United States  0.006460
# 5                         10224.0  United States  0.007784
# 6                         11066.0  United States  0.005836
# 7                         17521.0  United States  0.015224
# 8                         16934.0  United States  0.018242
# 9                         21640.0  United States  0.021756
# 10                        23629.0  United States  0.025042
# 11                        25236.0  United States  0.029124
# 12                        22779.0  United States  0.025356
# 13                        38317.0  United States  0.068430
# 14                        39059.0  United States  0.064702
# 15                        45018.0  United States  0.081244
# 16                        32837.0  United States  0.059539
# 17                        52921.0  United States  0.107253
# 18                        44521.0  United States  0.089192
# 19                        46433.0  United States  0.121114
# 20                        31749.0  United States  0.071935
# 21                        42388.0  United States  0.081937
# 22                        20115.0  United States  0.032451
# 23                        16357.0  United States  0.018370
# 24                        10127.0  United States  0.006587
# 25                        12730.0  United States  0.008880
# 26                        11385.0  United States  0.007170
# 27                          575.0     Austin, TX  0.006480
# 28                          431.0     Austin, TX  0.002640
# 85   0.004141
# 86   0.007210
# 87   0.005266
# 88   0.038538
# 89   0.101713
# 90   0.139783
# 91   0.066945
# 92   0.016346
# 93   0.108411
# 94   0.020859
# 95   0.042281
# 96   0.163819
# 97   0.027066
# 98   0.093272
# 99   0.050370
# 100  0.041378
# 101  0.028509
# 102  0.009471
# 103  0.002384
# 104  0.004946
# 105  0.001374
# 106  0.006931
# 107  0.010563
# 108  0.003742
# 109  0.021298
#
# [110 rows x 7 columns]

# %%
# grab columns we want about wage data 
wage_by_gender[["Gender",
                "Year",
               "Detailed Occupation",
               "Average Wage",
               "Average Wage Appx MOE",
               "Total Population",
               "Total Population MOE Appx",
                "Geography"]]

wage_by_race[["Race",
             "Year",
             "Detailed Occupation",
             "Average Wage",
             "Average Wage Appx MOE",
             "Total Population",
             "Total Population MOE Appx",
             "Geography"]]

wage_distribution[['Wage Bin',
                 'Year',
                 'Total Population',
                 'Total Population MOE Appx',
                 'Geography',
                 'share']]
# Out:
#       Wage Bin  Year  Total Population  Total Population MOE Appx  \
# 0    $130-140k  2017           1219921               27004.731372
# 1       $200k+  2017            292893               13130.056698
# 2    $190-200k  2017             16152                3118.217360
# 3      $10-20k  2017          19419097              100828.642897
# 4      $20-30k  2017          21457270              105142.742730
# 5    $180-190k  2017             38667                4820.259606
# 6      $30-40k  2017          19361189              100700.912684
# 7      $40-50k  2017          15445707               91305.365256
# 8    $170-180k  2017             37423                4742.324025
# 9      $50-60k  2017          12473792               82969.135682
# 10     $60-70k  2017           9664187               73784.452967
# 11   $160-170k  2017             47938                5365.103383
# 12     $70-80k  2017           6984904               63333.917699
# 13     $80-90k  2017           5296939               55482.703567
# 14   $150-160k  2017            109875                8102.179444
# 15    $90-100k  2017           3572079               45837.374795
# 16   $100-110k  2017           3805887               47275.338685
# 17   $140-150k  2017             69732                6465.063286
# 18   $110-120k  2017           1888638               33523.927213
# 19   $120-130k  2017           2195301               36105.257430
# 20   $130-140k  2017             93026                7460.200161
# 21      < $10K  2017          17420601               96240.393102
# 22   $140-150k  2017            904007               23271.676251
# 23   $120-130k  2017            188618               10581.707916
# 24   $150-160k  2017           1245986               27289.272033
# 25   $160-170k  2017            627113               19400.987295
# 26   $110-120k  2017            148444                9402.749984
# 27   $170-180k  2017            492628               17203.187513
# 28   $180-190k  2017            457330               16577.394720
# 29   $100-110k  2017            309101               13479.475868
# ..         ...   ...               ...                        ...
# 138    $50-60k  2014            939065               22820.105543
# 139  $110-120k  2014           1460431               29515.602497
# 140  $140-150k  2014             61282                6061.842761
# 141     $200k+  2014           2762472               40403.766737
# 142  $150-160k  2014            997029               24427.883822
# 143    $60-70k  2014            655556               19315.301911
# 144  $150-160k  2014             85530                7153.952928
# 145    $60-70k  2014           8509041               69419.534617
# 146    $10-20k  2014          21216573              104220.818639
# 147     < $10K  2014          19175353               99922.424060
# 148  $160-170k  2014             37353                4737.458834
# 149    $70-80k  2014            473147               16543.953996
# 150  $160-170k  2014            458890               16604.290690
# 79                             53832                           4204.071003
# 80                             11015                           1737.385680
# 81                             21663                           2909.255747
# 82                              2219                            731.207905
# 83                              3750                           1497.571701
# 84                             60187                           4125.176966
# 85                             45900                           4425.789873
# 86                             21748                           2485.354301
# 87                             52255                           4126.908770
# 88                             35756                           3740.748722
# 89                              1069                            495.665210
# 90                             29808                           3501.300615
# 91                             11129                           2292.573445
# 92                               344                            314.226033
# 93                             44222                           3257.077371
# 94                             34409                           3333.601356
# 95                             27913                           3073.191501
# 96                             15588                           2562.337995
# 97                             51960                           4073.599146
# 98                              8539                           2203.452064
# 99                             13258                           1997.711190
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Austin Basics (Ashley)
# - Propery values over time
# - Population changes over time
# - Wage distribution over time

# %%
# charts on property values over time

# %%
# charts on population changes over time 
# show which working ages live here
# include age nativity

# %%
# charts on wage distribution over time 
# show which wage bins can afford to live here and the # against total population

# %% [markdown]
# ## Austin Income Differences (Valeria & Vincent)
# - Wage vs gender over time
# - Wage vs race over time

# %%
# charts on wage vs gender over time 
# what is the gender/occupation that can afford to live in austin each year?
# what is the gender/occupation that cannot afford to live in austin each year?

# %%
# charts on wage vs race over time 
# what is the race/occupation that can afford to live in austin each year?
# what is the race/occupation that cannot afford to live in austin each year?

# %% [markdown]
# ## Austin Industry Information (Mark)
# - Changes in industry over time

# %%
Industry = []
Workforce = []
Year = []


Industry_grouping = employment_by_industry[['Year','Industry','Workforce by Industry and Gender']].groupby('Industry')
Industry_grouping.head()




# for industry in Industry_grouping:
#     Industry.append(industry).['Industry']
#     Workforce.append(industry).[('Workforce by Industry and Gender')]
#     Year.append(industry).[('Year')]
# get necessary data from table for chart


# atx_property = property_value.loc[property_value["Geography"] == "Austin, TX"]
# atx_property = atx_property.loc[atx_property["ID Value Bucket"] >= 13]
# atx_property = atx_property.sort_values("ID Value Bucket")


# charts on industry changes over time 
# what trends do we see in industry?
# which genders/races typically work in the top industry? can they afford to live in austin each year?
# which genders/races typically work in the bottom industry? can they afford to live in austin each year?
# Out:
#     Year                                           Industry  \
# 0   2017                               Educational Services
# 1   2017                              Public Administration
# 2   2017       Other Services, Except Public Administration
# 3   2017          Mining, Quarrying, & Oil & Gas Extraction
# 4   2017                      Accommodation & Food Services
# 5   2017                                       Construction
# 6   2017                  Arts, Entertainment, & Recreation
# 7   2017                                      Manufacturing
# 8   2017                    Health Care & Social Assistance
# 9   2017                                    Wholesale Trade
# 10  2017           Agriculture, Forestry, Fishing & Hunting
# 11  2017                                       Retail Trade
# 12  2017  Administrative & Support & Waste Management Se...
# 13  2017                       Transportation & Warehousing
# 14  2017              Management of Companies & Enterprises
# 15  2017                                          Utilities
# 16  2017     Professional, Scientific, & Technical Services
# 17  2017                                        Information
# 18  2017                     Real Estate & Rental & Leasing
# 19  2017                                Finance & Insurance
# 20  2016                                       Construction
# 21  2016                               Educational Services
# 22  2016                                       Retail Trade
# 23  2016       Other Services, Except Public Administration
# 24  2016          Mining, Quarrying, & Oil & Gas Extraction
# 25  2016  Administrative & Support & Waste Management Se...
# 26  2016                       Transportation & Warehousing
# 27  2016                  Arts, Entertainment, & Recreation
# 28  2016                                      Manufacturing
# 29  2016              Management of Companies & Enterprises
# ..   ...                                                ...
# 70  2014                                        Information
# 71  2014                       Transportation & Warehousing
# 72  2014                                       Construction
# 73  2014       Other Services, Except Public Administration
# 74  2014                               Educational Services
# 75  2014              Management of Companies & Enterprises
# 76  2014          Mining, Quarrying, & Oil & Gas Extraction
# 77  2014                              Public Administration
# 78  2014     Professional, Scientific, & Technical Services
# 79  2014                                       Retail Trade
# 80  2013                  Arts, Entertainment, & Recreation
# 81  2013  Administrative & Support & Waste Management Se...
# 82  2013          Mining, Quarrying, & Oil & Gas Extraction
# 83  2013                                          Utilities
# 84  2013     Professional, Scientific, & Technical Services
# 85  2013                      Accommodation & Food Services
# 86  2013                                Finance & Insurance
# 87  2013                               Educational Services
# 88  2013                                       Construction
# 89  2013           Agriculture, Forestry, Fishing & Hunting
# 90  2013       Other Services, Except Public Administration
# 91  2013                       Transportation & Warehousing
# 92  2013              Management of Companies & Enterprises
# 93  2013                    Health Care & Social Assistance
# 94  2013                                      Manufacturing
# 95  2013                              Public Administration
# 96  2013                                        Information
# 97  2013                                       Retail Trade
# 98  2013                                    Wholesale Trade
# 99  2013                     Real Estate & Rental & Leasing
#
#     Workforce by Industry and Gender
# 0                              58591
# 1                              29054
# 2                              26993
# 3                               2802
# 4                              48958
# 5                              41460
# 6                              13123
# 7                              41586
# 8                              52161
# 9                               9351
# 10                              1548
# 11                             47784
# 12                             22313
# 13                             17502
# 14                               963
# 15                              3421
# 16                             75427
# 17                             19041
# 18                             18199
# 19                             20807
# 20                             42818
# 21                             53372
# 22                             60380
# 23                             27626
# 24                              1559
# 25                             24394
# 26                             13855
# 27                             14465
# 28                             40325
# 29                               542
# ..                               ...
# 70                             15138
# 71                             12814
# 72                             33731
# 73                             24772
# 74                             56249
# 75                               679
# 76                              1965
# 77                             27129
# 78                             63053
# 79                             53832
# 80                             11015
# 81                             21663
# 82                              2219
# 83                              3750
# 84                             60187
# 85                             45900
# 86                             21748
# 87                             52255
# 88                             35756
# 89                              1069
# 90                             29808
# 91                             11129
# 92                               344
# 93                             44222
# 94                             34409
# 95                             27913
# 96                             15588
# 97                             51960
# 98                              8539
# 99                             13258
#
# [100 rows x 3 columns]

# %%
Industry_grouping.set_index('Year', inplace=True)
Industry_grouping.groupby('Industry')['Workforce by Industry and Gender'].plot(legend=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6c048781e4ba> in <module>
# ----> 1 Industry_grouping.set_index('Year', inplace=True)
#       2 Industry_grouping.groupby('Industry')['Workforce by Industry and Gender'].plot(legend=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'set_index' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
y2015 = Industry_grouping.loc[Industry_grouping["Year"] == 2015]
y2016 = Industry_grouping.loc[Industry_grouping["Year"] == 2016]
y2017 = Industry_grouping.loc[Industry_grouping["Year"] == 2017]
Ind = Industry_grouping.loc[Industry_grouping["Industry"] == 'Education']

# Industry_grouping = employment_by_industry[['Year','Industry','Workforce by Industry and Gender']].groupby('Industry')
# Industry_grouping.head()

#identify x/y values and error for chart
workforce2015 = Industry_grouping.loc[Industry_grouping["Year"] == 2015]["Workforce by Industry and Gender"]
y1 = Industry_grouping.loc[Industry_grouping["Year"] == 2015]
workforce2016 = Industry_grouping.loc[Industry_grouping["Year"] == 2016]["Workforce by Industry and Gender"]
y2 = Industry_grouping.loc[Industry_grouping["Year"] == 2016]
workforce2017 = Industry_grouping.loc[Industry_grouping["Year"] == 2017]["Workforce by Industry and Gender"]
y3 = Industry_grouping.loc[Industry_grouping["Year"] == 2017]

# graph values on a bar chart 
fig, ax = plt.subplots()
ax.bar(workforce2015, y1,alpha=0.5, label="2015", color='b')
ax.bar(workforce2016,y2, alpha=0.5, label="2016", color='g')
ax.bar(workforce2017,y3,alpha=0.5,label ="2017",color='y')

# add labels and title 
ax.set_xlabel("Industry")
ax.set_ylabel("Jobs")
ax.set_title("Employment by Industry in Austin, Texas between 2015-2017")
plt.xticks(x1, rotation = 'vertical')
ax.set_xticklabels(('Educational Services',
                    'Public Administration',
                    'Other Services, Except Public Administration',
                    'Mining, Quarrying, & Oil & Gas Extraction',
                    'Accommodation & Food Services',
                    'Construction',
                    'Arts, Entertainment, & Recreation',
                    'Manufacturing',
                    'Health Care & Social Assistance',
                    'Wholesale Trade',
                    'Agriculture, Forestry, Fishing & Hunting',
                    'Retail Trade',
                    'Administrative & Support & Waste Management9',                    
                    'Transportation & Warehousing',
                    'Management of Companies & Enterprises',                    
                    'Utilities',            
                    'Professional, Scientific, & Technical Service',
                    'Information',                    
                    'Real Estate & Rental & Leasing',                    
                    'Finance & Insurance'))
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1d18cc8f0ca2> in <module>
# ----> 1 y2015 = Industry_grouping.loc[Industry_grouping["Year"] == 2015]
#       2 y2016 = Industry_grouping.loc[Industry_grouping["Year"] == 2016]
#       3 y2017 = Industry_grouping.loc[Industry_grouping["Year"] == 2017]
#       4 Ind = Industry_grouping.loc[Industry_grouping["Industry"] == 'Education']
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'loc' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
# Add labels to X and Y axes :: Add title
plt.title("Industry Over Time In Austin")
plt.xlabel("Industry")
plt.ylabel("Workforce")

# i = len(Industry)

# plt.bar(i, [Industry])

# # # Create a legend for the chart
# # plt.legend(handles=[Industry, Workforce], loc="best")
# # # Plot the charts and apply some styling
Industry = plt.bar(Year, Industry, color="red", label="Industry")
Workforce, = plt.bar(Year, Workforce, color="blue", label="Workforce")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f7b74ea1c43a> in <module>
#      12 # # plt.legend(handles=[Industry, Workforce], loc="best")
#      13 # # # Plot the charts and apply some styling
# ---> 14 Industry = plt.bar(Year, Industry, color="red", label="Industry")
#      15 Workforce, = plt.bar(Year, Workforce, color="blue", label="Workforce")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2223
#    2224         if orientation == 'vertical':
# -> 2225             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2226             if log:
#    2227                 self.set_yscale('log', nonposy='clip')
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2134
#    2135         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2136         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2137         return kwargs
#    2138
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2116                 # We only need to update if there is nothing set yet.
#    2117                 if not axis.have_units():
# -> 2118                     axis.update_units(data)
#    2119
#    2120             # Check for units in the kwargs, and if present update axis
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1471         neednew = self.converter != converter
#    1472         self.converter = converter
# -> 1473         default = self.converter.default_units(data, self)
#    1474         if default is not None and self.units is None:
#    1475             self.set_units(default)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     101         # default_units->axis_info->convert
#     102         if axis.units is None:
# --> 103             axis.set_units(UnitData(data))
#     104         else:
#     105             axis.units.update(data)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     167         self._counter = itertools.count()
#     168         if data is not None:
# --> 169             self.update(data)
#     170
#     171     def update(self, data):
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     184         data = np.atleast_1d(np.array(data, dtype=object))
#     185
# --> 186         for val in OrderedDict.fromkeys(data):
#     187             if not isinstance(val, (str, bytes)):
#     188                 raise TypeError("{val!r} is not a string".format(val=val))
#
# TypeError: unhashable type: 'numpy.ndarray'
